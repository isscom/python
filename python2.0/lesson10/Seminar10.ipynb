# %% [markdown]
# ### Задача №57. ###
# 1. Прочесть с помощью pandas файл california_housing_test.csv, который находится в папке sample_data
# 2. Посмотреть сколько в нем строк и столбцов
# 3. Определить какой тип данных имеют столбцы

# %%
import pandas as pd

# %%
# 1 Прочесть с помощью pandas файл california_housing_test.csv, который находится в папке sample_data
# data_frame (df)
df = pd.read_csv("sample_data/california_housing_test.csv")
df.head() #  первые 5 строк на экран (если указываем в скобках, то выводит это кол-во строк)
df.tail() #  последние 5 строк по аналогии
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
# 2 Посмотреть сколько в нем строк и столбцов
df.shape
# Out:
# (3000, 9)

# %%
# 3 Определить какой тип данных имеют столбцы
df.dtypes # вывод типа данных по каждому столбцу
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.info() # вывод информацию: какие данные есть
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %% [markdown]
# ### Задача №59. ###
# 1. Проверить есть ли в файле пустые значения
# 2. Показать median_house_value где median_income < 2
# 3. Показать данные в первых 2 столбцах
# 4. Выбрать данные где housing_median_age < 20 и median_house_value > 70000

# %%
# 1 Проверить есть ли в файле пустые значения
df.isnull().sum()

# %%
# 2 Показать median_house_value где median_income < 2
df.loc[df['median_income'] < 2, 'median_house_value']

# %%
# 3 Показать данные в первых 2 столбцах
df[['longitude', 'latitude']] # один столбец выводим - передаем в виде строки, несколько стобцов - в виде списка

# %%
# обращаемся к номеру строки
df.iloc[2999]

# обращаеся к столбцу: df['название столбца']

# %%
df.iloc[2999]['longitude']

# %%
# 4 Выбрать данные где housing_median_age < 20 и median_house_value > 70000
df[(df['housing_median_age'] < 20) & (df['median_house_value'] > 70000)]
# & - и(and)
# | - или(or)

# %% [markdown]
# ### Задача №61. ###
# 1. Определить какое максимальное и минимальное значение median_house_value
# 2. Показать максимальное median_house_value, где median_income = 3.1250
# 3.Узнать какая максимальная population в зоне минимального значения median_house_value

# %%
# 1 Определить какое максимальное и минимальное значение median_house_value
print(df['median_house_value'].min(), df['median_house_value'].max())
print()
# еще один вариант:
df['median_house_value'].describe()

# %%
# 2 Показать максимальное median_house_value, где median_income = 3.1250

# ДЕЛАЕМ ПОСТЕПЕННО

# 2.1
df[df['median_income'] == 3.1250]

# %%
# 2.2 Можем обратиться к столбцу median_house_value вот так:
df[df['median_income'] == 3.1250]['median_house_value']

# %%
# 2.2 А можем через функцию loc
df.loc[df['median_income'] == 3.1250, 'median_house_value']

# %%
# 2.3
df.loc[df['median_income'] == 3.1250, 'median_house_value'].max()

# %%
# 3 Узнать какая максимальная population в зоне минимального значения median_house_value
df[df['median_house_value'] == df['median_house_value'].min()]['population'].max()

# %% [markdown]
# ### Задача 40. ###
# Работать с файлом california_housing_train.csv, который находится в папке sample_data. Определить среднюю стоимость дома, где кол-во людей от 0 до 500 (population)

# %%
# Домашнее задание
import pandas as pd

df = pd.read_csv("sample_data/california_housing_train.csv")
# Решение 1
# df.loc[df['population'] < 500, 'median_house_value'].describe()['mean']
# .describe() создает новый data frame
# Решение 2
# df.loc[df['population'] < 500, 'median_house_value'].mean()
# Решение 3
df[df['population'] < 500]['median_house_value'].mean()

# 2 8 10 15 18 20 27 34
# mean() - (2+8+10+15+18+20+27+34) / 8 = 16.75
# median() - (15+18) / 2 = 16.5

df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# ### Задача 42. ###
# Узнать какая максимальная households в зоне минимального значения population

# %%
df[df['population'] == df['population'].min()]['households'].max()
# Out:
# 4.0

# %% [markdown]
# #Семинар 10#
#
#
# ---

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8)) # сначала указываем размер
plt.title('Карта') # название графика
plt.xlabel('Долгота') # ось икс
plt.ylabel('Широта') # ось игрек

sns.scatterplot(data=df, x = 'longitude', y = 'latitude', hue = 'median_house_value');
# x - широта, y - долгота, hue - цветовая палитра (медианная стоимость здания)
# sns.scatterplot(x = df['longitude'], y = df['latitude'], hue = df['median_house_value']);
plt.legend(df['median_house_value'], title='Стоимость дома');

# %% [markdown]
# ###Задача №63.###
# 1. Изобразите отношение households к population с помощью точечного графика
# 2. Визуализировать longitude по отношения к median_house_value, используя линейный график
# 3. Представить гистограмму по housing_median_age
# 4. Изобразить гистограмму по median_house_value с оттенком housing_median_age

# %%
# 1. Изображаем отношение households к population точечным графиком
sns.scatterplot(data=df, x='population', y='households');
# ; в конце - чтобы не выводилась лишняя строка

# %%
# 2. Линейным графиком визуализируем longitude по отношению к median_house_value
plt.figure(figsize=(14,8))
sns.lineplot(data=df, x='longitude', y='median_house_value');
# sns.relplot(data=df, x='longitude', y='median_house_value', kind='line');

# %%
# 3. Гистограмма по housing_media_age
sns.histplot(x=df['housing_median_age']);

# %%
# 4. Гистограмма по median_house_value с оттенком (hue) house_median_age
sns.histplot(x=df['median_house_value'], hue=df['housing_median_age']);

# %% [markdown]
# ###Задача №65.###
# Написать EDA для датасета про пингвинов
# Необходимо:
# * Использовать 2-3 точечных графика
# * Применить доп измерение в точечных графиках, используя аргументы hue, size, stile
# * Использовать PairGrid с типом графика на ваш выбор
# * Изобразить Heatmap
# * Использовать 2-3 гистограммы
#
#
# *Чтобы подключить датасет c пингвинами, воспользуйтесь данным скриптом:*
#
#
# ```
# penguins = sns.load_dataset("penguins")
# penguins.head()
# ```

# %% [markdown]
# ###Задача №67.###
# 1. Создать новый столбец в таблице с пингвинами, который будет отвечать за показатель длины клюва пингвина.
# * high - длинный(от 42)
# * middle - средний(от 35 до 42)
# * low - маленький(до 35)
#
#
#
# *Чтобы подключить датасет с пингвинами, воспользуйтесь данным скриптом:*
#
# ```
# penguins = sns.load_dataset("penguins")
# penguins.head()
# ```

# %% [markdown]
# ###Задача №69.###
# 1. Изобразить гистограмму по flipper_length_mm с оттенком height_group. Сделать анализ

# %% [markdown]
# ###Задача 44:###
# В ячейке ниже представлен код генерирующий DataFrame, которая состоит всего из 1 столбца. Ваша задача перевести его в one hot вид. Сможете ли вы это сделать без get_dummies?
#
#
# ```
# import random
# lst = ['robot'] * 10
# lst += ['human'] * 10
# random.shuffle(lst)
# data = pd.DataFrame({'whoAmI':lst})
# data.head()
# ```
# Статья про [one hot](https://colab.research.google.com/drive/1qKamnDiRmpRZkpiqWPkunBdAhmzhMcGz?usp=sharing) вид
